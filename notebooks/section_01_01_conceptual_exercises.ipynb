# %%
# notebooks/chapter_01/01_01_conceptual_exercises.ipynb (OPTIONAL, not necessary)

"""
Section 1.01: What is ML? - Conceptual Exercises

No code to run. Answer these questions to check understanding:

1. When would you use ML vs traditional rules?
2. What are the 3 types of ML?
3. What are the 7 stages of ML pipeline?
4. What's the security risk at each pipeline stage?
"""

# But honestly, skip this. Move to Section 1.02 where actual code starts.
